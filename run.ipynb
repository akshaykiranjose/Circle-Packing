# %%
from model import *
from utils import *

# %%
BATCHES = 200
EPOCHS = 1000

# %%
num_circles = 5
large_radius =  1.
small_radius = 0.3701919

# %%
eye = one_hot(np.arange(0, num_circles), num_circles)
Input = tf.reshape(tf.tile(eye, [BATCHES, 1]) ,[-1, num_circles, num_circles])

# %%
loss = CCE()
optim = Adam(learning_rate = 0.0005)
autoencoder = Autoencoder(num_circles, large_radius, small_radius)

# %%
centres = autoencoder.centres(eye)

plot_circles(centres, large_radius, small_radius)

# %%
autoencoder.noise.alpha = 1/2
for epoch in tqdm(range(EPOCHS)):
    centres_ae = autoencoder.centres(eye)
    plot_circles(centres_ae, large_radius, small_radius, 
                 save=False, savename=f'saved images/{num_circles}CinC_ep{epoch}.png')
    
    for inputs in Input:           
            with tf.GradientTape() as tape:
                curr_loss = loss(autoencoder(inputs), inputs)
                grads = tape.gradient(curr_loss, autoencoder.trainable_variables)
            optim.apply_gradients(zip(grads, autoencoder.trainable_variables))
# Out:
# ...
#   7%|██████▍                                                                                        | 68/1000 [15:59<3:31:17, 13.60s/it]
